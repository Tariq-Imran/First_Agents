# %% [markdown]
# ## Setup

# %%
import os
from dotenv import load_dotenv

# Load envirinment
load_dotenv()

# Get data from .env file
openai_api_key= os.getenv("OPENAI_API_KEY")
langsmith_api_key=os.getenv("LANGSMITH_API_KEY")
langsmith_tracing=os.getenv("LANGSMITH_TRACING")
langsmith_project=os.getenv("LANGSMITH_PROJECT")
langsmith_endpoint=os.getenv("LANGSMITH_ENDPOINT")

# %% [markdown]
# ## Human and AI Messages

# %%
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage

agent = create_agent(
    model="gpt-5-nano-2025-08-07",
    system_prompt="You are an expert in lead generation"
)

# %%
human_msg = HumanMessage("Eco friendly shopping bags")
result = agent.invoke({"messages": [human_msg]})

# %%
print(result["messages"][-1].content)
# Out:
# Great topic. Here’s a practical guide to eco-friendly shopping bags plus a ready-to-use lead-generation plan you can deploy to attract retailers, brands, or event organizers.
#
# 1) Quick guide to eco-friendly bag options
# - Cotton/Canvas totes: Durable, reusable, easy to print branding. Pros: classic look, comfortable. Cons: higher upfront cost, heavier, uses water in production.
# - Jute bags: Strong, natural fiber, good for branding. Pros: biodegradable, attractive texture. Cons: higher price per unit, moisture sensitivity.
# - Hemp or linen: Highly durable, sustainable fibers. Pros: premium feel, strong. Cons: higher cost, limited suppliers.
# - Recycled materials (RPET, recycled cotton): Pros: reduces waste, good for brand stories. Cons: recyclability varies by end-of-life stream; RPET still behaves like plastic in some contexts.
# - Plant-based plastics (PLA, PHA): Compostable under industrial composting conditions. Pros: good for branding on certain campaigns. Cons: not always compostable in home composting; requires appropriate facilities.
# - Non-woven PP bags (less eco-friendly than natural fibers): Durable and inexpensive, but not always aligned with core sustainability claims. Use with caution if “eco-friendly” is a top selling point.
# - Customization options: size, gussets, handles, color, screen printing, embroidery, tags, QR codes, and packaging labels.
#
# 2) What buyers care about most
# - Total cost of ownership: upfront price, durability, number of uses, and end-of-life options.
# - Durability and practicality: load capacity, washability, foldability, and leakage resistance.
# - Brandability: high-quality printing, color fidelity, and placement options.
# - Lead times and MOQs: scalable for campaigns or store openings.
# - End-of-life claims: recyclability, compostability, or refill programs; third-party certifications.
# - Supply chain reliability: supplier stability, traceability, and ethical practices.
#
# 3) Lead-generation strategy for selling eco-friendly bags (B2B)
#
# A. Ideal customers (ICP)
# - Retailers and supermarkets replacing single-use bags
# - E-commerce brands needing branded bags for packaging
# - Event organizers, conferences, trade shows
# - Universities, hospitals, hotels, and hospitality groups
# - NGOs and government programs promoting sustainability
#
# B. Value proposition
# - Durable, customizable eco-friendly bags that align with sustainability goals and boost brand visibility, with scalable MOQs, fast lead times, and clear end-of-life options.
#
# C. Funnel assets
# - Awareness
#   - Blog posts: “10 Ways to Replace Plastic Bags in Your Store,” “Total Cost of Ownership for Reusable Bags,” “Choosing the Right Material for Branded Bags”
#   - Infographics: lifecycle of a reusable bag, cost-savings over time
# - Consideration
#   - Product data sheets (materials, sizes, specs)
#   - Case studies (quantified outcomes: cost savings, reuse rates, brand lift)
#   - Sustainability notes (certifications, supply-chain transparency)
# - Decision
#   - ROI calculator or cost-per-use tool
#   - Samples kit and quick-quote form
#   - Customization options and lead-time estimator
#
# D. Lead magnets (to capture contact details)
# - “Ultimate Guide to Choosing Reusable Shopping Bags” (downloadable PDF)
# - “Sustainability ROI Calculator for Bag Programs” (interactive or spreadsheet)
# - “Custom Bag Specs Cheat Sheet” (spec template)
# - “Free Sample Kit” (request form with shipping details)
# - “Bulk Pricing & Lead Time Estimator” (live calculator)
#
# E. Channels and tactics
# - LinkedIn and Google Search ads targeting sustainability managers, procurement, marketing, and store operations roles
# - Retargeting ads on LinkedIn, Google Display
# - Email nurture campaigns to new leads (5-step sequence)
# - Content syndication in industry newsletters, packaging associations
# - Trade shows and local sustainability events (booth, demos, live samples)
#
# F. Lead capture and follow-up
# - Form fields to collect: name, company, role, email, phone, country, bag type interest, monthly quantity, customization needs, deadline, certifications, budget, shipping address
# - Immediate follow-up: automatic welcome email with the “Ultimate Guide” link and a promise of a quick quote
# - Sales nurture: 4–6 touch sequence with a mix of case studies, sample options, ROI insights, and a call to schedule a quick call
# - Qualification: use a standard BANT-like approach (Budget, Authority, Need, Timeline) to route to the right sales track
#
# G. Objections and replies
# - Price: emphasize long-term savings, unit cost per use, and any volume discounts; show ROI
# - Durability: share test results, warranty information, and warranty terms
# - Compostability: explain actual end-of-life pathways and certifications; be clear about industrial vs home composting
# - Customization and MOQs: offer scalable options, design services, and partial MOQs if feasible
# - Lead times: provide realistic timelines and options for accelerating production
#
# H. Metrics to track
# - Cost per lead (CPL), click-through rate (CTR), conversion rate on landing pages
# - Marketing-sourced SQLs (sales-qualified leads)
# - Time-to-first-response and win rate
# - Average order value (AOV) and customer lifetime value (CLV)
# - Lead quality feedback from sales (to refine ICP)
#
# 4) Example assets you can deploy quickly
#
# A. Landing page structure
# - Hero: “Ditch single-use plastic. Brandable, durable, eco-friendly bags your customers will reuse.”
# - Subhead: “Customizable bags in cotton, jute, hemp, and RPET with fast lead times and end-of-life options.”
# - Key benefits: durability, customization, sustainability claims, sample kit
# - CTAs: “Get a Free Sample Kit,” “Request a Quote,” “Download the Buyer's Guide”
# - Lead capture form: name, company, role, email, phone, country, bag type interest, monthly quantity, deadline
#
# B. Sample form fields
# - Full name, Company, Role, Email, Phone
# - Country, Estimated monthly quantity, Desired material, Customization (print/logo), Deadline
# - Sustainability certifications needed (optional)
#
# C. Email sequence (5 touches)
# - Email 1: Welcome and guide download link
# - Email 2: Case study snippet showing cost savings and reuse rate
# - Email 3: ROI calculator results or a quick quote request
# - Email 4: Sample kit shipping info and a scheduling link
# - Email 5: Final nudge with a limited-time offer or discount for first order
#
# D. LinkedIn/Ad copy examples
# - Awareness: “Replace disposable bags with durable, eco-friendly options. Customizable, scalable, and brand-ready.”
# - Consideration: “See how retailers cut plastic bag usage by 40%+ with our reusable bags – download the guide.”
# - Conversion: “Ready for a quote? Get a sample kit in 3–5 days. MOQ-friendly and fast lead times.”
#
# 5) Compliance and truthful marketing
# - Avoid vague or unverifiable “green” claims. If you claim compostability, specify conditions (industrial composting) and cite third-party certifications where possible.
# - Be transparent about materials, end-of-life options, and supply-chain sourcing.
# - Provide accurate lead times and MOQs to prevent misaligned expectations.
#
# 6) Next steps and quick questions to tailor
# - Is your primary target B2B (retailers/brands) or B2C (end consumers via campaigns)?
# - Which materials are you focusing on (cotton, jute, RPET, hemp, etc.) and what pricing bands do you target?
# - Do you have existing content (logos, case studies, data sheets) to repurpose, or should I draft new pieces from scratch?
# - What channels do you prefer for initial demand (LinkedIn, Google, email nurture, events)?
# - Do you want a ready-to-launch landing page and a full 8-week content/ads plan, or something more incremental?
#
# If you’d like, I can tailor this into a ready-to-implement plan with specific copy, asset templates, and a 60-day calendar focused on your target markets. Just tell me your preferred materials and target audience, and I’ll customize it.

# %%
print(type(result["messages"][-1]))
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
for msg in result["messages"]:
    print(f"{msg.type}: {msg.content}\n")
# Out:
# human: Eco friendly shopping bags
#
# ai: Great topic. Here’s a practical guide to eco-friendly shopping bags plus a ready-to-use lead-generation plan you can deploy to attract retailers, brands, or event organizers.
#
# 1) Quick guide to eco-friendly bag options
# - Cotton/Canvas totes: Durable, reusable, easy to print branding. Pros: classic look, comfortable. Cons: higher upfront cost, heavier, uses water in production.
# - Jute bags: Strong, natural fiber, good for branding. Pros: biodegradable, attractive texture. Cons: higher price per unit, moisture sensitivity.
# - Hemp or linen: Highly durable, sustainable fibers. Pros: premium feel, strong. Cons: higher cost, limited suppliers.
# - Recycled materials (RPET, recycled cotton): Pros: reduces waste, good for brand stories. Cons: recyclability varies by end-of-life stream; RPET still behaves like plastic in some contexts.
# - Plant-based plastics (PLA, PHA): Compostable under industrial composting conditions. Pros: good for branding on certain campaigns. Cons: not always compostable in home composting; requires appropriate facilities.
# - Non-woven PP bags (less eco-friendly than natural fibers): Durable and inexpensive, but not always aligned with core sustainability claims. Use with caution if “eco-friendly” is a top selling point.
# - Customization options: size, gussets, handles, color, screen printing, embroidery, tags, QR codes, and packaging labels.
#
# 2) What buyers care about most
# - Total cost of ownership: upfront price, durability, number of uses, and end-of-life options.
# - Durability and practicality: load capacity, washability, foldability, and leakage resistance.
# - Brandability: high-quality printing, color fidelity, and placement options.
# - Lead times and MOQs: scalable for campaigns or store openings.
# - End-of-life claims: recyclability, compostability, or refill programs; third-party certifications.
# - Supply chain reliability: supplier stability, traceability, and ethical practices.
#
# 3) Lead-generation strategy for selling eco-friendly bags (B2B)
#
# A. Ideal customers (ICP)
# - Retailers and supermarkets replacing single-use bags
# - E-commerce brands needing branded bags for packaging
# - Event organizers, conferences, trade shows
# - Universities, hospitals, hotels, and hospitality groups
# - NGOs and government programs promoting sustainability
#
# B. Value proposition
# - Durable, customizable eco-friendly bags that align with sustainability goals and boost brand visibility, with scalable MOQs, fast lead times, and clear end-of-life options.
#
# C. Funnel assets
# - Awareness
#   - Blog posts: “10 Ways to Replace Plastic Bags in Your Store,” “Total Cost of Ownership for Reusable Bags,” “Choosing the Right Material for Branded Bags”
#   - Infographics: lifecycle of a reusable bag, cost-savings over time
# - Consideration
#   - Product data sheets (materials, sizes, specs)
#   - Case studies (quantified outcomes: cost savings, reuse rates, brand lift)
#   - Sustainability notes (certifications, supply-chain transparency)
# - Decision
#   - ROI calculator or cost-per-use tool
#   - Samples kit and quick-quote form
#   - Customization options and lead-time estimator
#
# D. Lead magnets (to capture contact details)
# - “Ultimate Guide to Choosing Reusable Shopping Bags” (downloadable PDF)
# - “Sustainability ROI Calculator for Bag Programs” (interactive or spreadsheet)
# - “Custom Bag Specs Cheat Sheet” (spec template)
# - “Free Sample Kit” (request form with shipping details)
# - “Bulk Pricing & Lead Time Estimator” (live calculator)
#
# E. Channels and tactics
# - LinkedIn and Google Search ads targeting sustainability managers, procurement, marketing, and store operations roles
# - Retargeting ads on LinkedIn, Google Display
# - Email nurture campaigns to new leads (5-step sequence)
# - Content syndication in industry newsletters, packaging associations
# - Trade shows and local sustainability events (booth, demos, live samples)
#
# F. Lead capture and follow-up
# - Form fields to collect: name, company, role, email, phone, country, bag type interest, monthly quantity, customization needs, deadline, certifications, budget, shipping address
# - Immediate follow-up: automatic welcome email with the “Ultimate Guide” link and a promise of a quick quote
# - Sales nurture: 4–6 touch sequence with a mix of case studies, sample options, ROI insights, and a call to schedule a quick call
# - Qualification: use a standard BANT-like approach (Budget, Authority, Need, Timeline) to route to the right sales track
#
# G. Objections and replies
# - Price: emphasize long-term savings, unit cost per use, and any volume discounts; show ROI
# - Durability: share test results, warranty information, and warranty terms
# - Compostability: explain actual end-of-life pathways and certifications; be clear about industrial vs home composting
# - Customization and MOQs: offer scalable options, design services, and partial MOQs if feasible
# - Lead times: provide realistic timelines and options for accelerating production
#
# H. Metrics to track
# - Cost per lead (CPL), click-through rate (CTR), conversion rate on landing pages
# - Marketing-sourced SQLs (sales-qualified leads)
# - Time-to-first-response and win rate
# - Average order value (AOV) and customer lifetime value (CLV)
# - Lead quality feedback from sales (to refine ICP)
#
# 4) Example assets you can deploy quickly
#
# A. Landing page structure
# - Hero: “Ditch single-use plastic. Brandable, durable, eco-friendly bags your customers will reuse.”
# - Subhead: “Customizable bags in cotton, jute, hemp, and RPET with fast lead times and end-of-life options.”
# - Key benefits: durability, customization, sustainability claims, sample kit
# - CTAs: “Get a Free Sample Kit,” “Request a Quote,” “Download the Buyer's Guide”
# - Lead capture form: name, company, role, email, phone, country, bag type interest, monthly quantity, deadline
#
# B. Sample form fields
# - Full name, Company, Role, Email, Phone
# - Country, Estimated monthly quantity, Desired material, Customization (print/logo), Deadline
# - Sustainability certifications needed (optional)
#
# C. Email sequence (5 touches)
# - Email 1: Welcome and guide download link
# - Email 2: Case study snippet showing cost savings and reuse rate
# - Email 3: ROI calculator results or a quick quote request
# - Email 4: Sample kit shipping info and a scheduling link
# - Email 5: Final nudge with a limited-time offer or discount for first order
#
# D. LinkedIn/Ad copy examples
# - Awareness: “Replace disposable bags with durable, eco-friendly options. Customizable, scalable, and brand-ready.”
# - Consideration: “See how retailers cut plastic bag usage by 40%+ with our reusable bags – download the guide.”
# - Conversion: “Ready for a quote? Get a sample kit in 3–5 days. MOQ-friendly and fast lead times.”
#
# 5) Compliance and truthful marketing
# - Avoid vague or unverifiable “green” claims. If you claim compostability, specify conditions (industrial composting) and cite third-party certifications where possible.
# - Be transparent about materials, end-of-life options, and supply-chain sourcing.
# - Provide accurate lead times and MOQs to prevent misaligned expectations.
#
# 6) Next steps and quick questions to tailor
# - Is your primary target B2B (retailers/brands) or B2C (end consumers via campaigns)?
# - Which materials are you focusing on (cotton, jute, RPET, hemp, etc.) and what pricing bands do you target?
# - Do you have existing content (logos, case studies, data sheets) to repurpose, or should I draft new pieces from scratch?
# - What channels do you prefer for initial demand (LinkedIn, Google, email nurture, events)?
# - Do you want a ready-to-launch landing page and a full 8-week content/ads plan, or something more incremental?
#
# If you’d like, I can tailor this into a ready-to-implement plan with specific copy, asset templates, and a 60-day calendar focused on your target markets. Just tell me your preferred materials and target audience, and I’ll customize it.

# %% [markdown]
# ## Altenative formats
# ## Strings
# ### There are situations where LangChain can infer the role from the context, and a simple string is enough to create a message.

# %%
agent = create_agent(
    model="gpt-5-nano-2025-08-07",
    system_prompt="You are a digital marketing expert",
)

# %% [markdown]
# ## Strings

# %%
result = agent.invoke({"messages": "Tell me about Facebook marketing"})
print(result["messages"][-1].content)
# Out:
# Here’s a comprehensive overview of Facebook marketing, covering both organic and paid strategies, what you should focus on, and a practical path to getting results.
#
# What Facebook marketing is
# - Facebook marketing combines organic content (posts, videos, groups, live video) with paid advertising to reach, engage, and convert audiences on Facebook and across Meta surfaces (Instagram, Messenger, and Facebook’s other placements).
# - It’s powerful for many goals: brand awareness, traffic, lead generation, app installs, catalog sales, and in-store or online conversions. Its strengths are deep targeting, robust measurement, and a large, diverse audience.
#
# Key components
#
# 1) Goals and funnel
# - Awareness: reach broad audiences and build familiarity (objective examples: Reach, Brand Awareness, Video Views).
# - Consideration: drive engagement, traffic, app installs, or lead generation (Objectives: Traffic, Engagement, App Installs, Leads, Video Views).
# - Conversion: drive purchases or sign-ups (Objectives: Conversions, Catalog Sales, Lead Generation with strong follow-up).
# - Retention/loyalty: re-engagement with existing customers, offers, and upsells.
#
# 2) Audience targeting
# - Custom Audiences: upload customer lists, website visitors (via Facebook Pixel), app users, engagement on your content.
# - Lookalike Audiences: find new people similar to your best customers (based on Custom Audiences).
# - Saved Audiences: combine demographics, interests, and behaviors for broader tests.
# - Retargeting: show ads to people who interacted with your site, video, or page but didn’t convert.
# - Exclusions: refine who not to show ads to (e.g., existing customers you’re targeting with retention campaigns).
#
# 3) Creative formats and placements
# - Ad formats: image ads, video ads, carousel ads (multiple images), collection ads (immersive shopping), instant experiences (full-screen immersive experiences), lead ads (capture contact info directly), dynamic/product ads (personalized product catalogs).
# - Video formats: short reels-style video ads, longer videos, stories ads, in-stream video ads.
# - Placements: automatic placements (Meta’s algorithm chooses where to show), or manual placements across Facebook News Feed, Instagram Feed, Reels, Stories, Messenger, and Audience Network.
# - Creative tips: clear one-message-per-ad, strong first 3 seconds, mobile-first design, captions for videos, and high-quality visuals.
#
# 4) Organic strategy
# - Content pillars: define 3–5 topics that align with audience interests and your brand (educational content, behind-the-scenes, product tips, user-generated content, community stories).
# - Posting cadence: consistent posting (daily or several times per week) with a mix of formats (short informative posts, videos, live streams, carousels).
# - Engagement & community: respond to comments quickly, run polls, ask questions, host live sessions, create and nurture Groups if relevant.
# - Optimization: track what resonates (reach, engagement rate, saves, shares, comments) and iterate.
#
# 5) Paid strategy and structure
# - Campaigns, ad sets, and ads: organizing by objective, audience, placement, and creative. Test variations systematically.
# - Budgeting: daily or lifetime budgets; start with modest testing budgets and scale on proven performance.
# - Bidding and optimization: options include Lowest Cost (no cap), Cost Cap, or Target ROAS. Consider Campaign Budget Optimization (CBO) or the newer Advantage-style automation for simplification and scale, depending on your needs.
# - Creative testing: run A/B tests for images vs. video, different hooks, CTAs, and formats. Use learnings to optimize both scope and creative.
# - Retargeting strategy: dedicated ad sets for warm audiences (e.g., viewed product page in last 7 days, added-to-cart but not purchased).
#
# 6) Tracking, analytics, and measurement
# - Meta Pixel: place a pixel on your site to measure conversions, optimize for events, and build audiences.
# - Events API / server-side tracking: complements the Pixel, helps with reliability after iOS 14+ privacy changes.
# - Aggregated Event Measurement (AEM): recommended approach for measurement when users opt out of tracking.
# - Key metrics: ROAS (return on ad spend), CPA (cost per acquisition), CPC, CPM, CTR, conversion rate, average order value, frequency, reach, engagement metrics, and video view depth.
# - Attribution windows: common windows are 7-day click and 1-day view; tailor based on typical customer journey.
# - Reporting cadence: set up dashboards (Ads Manager reports, custom ROAS dashboards) and review weekly; deep-dive monthly.
#
# 7) Tools and setup you’ll likely use
# - Meta Business Suite / Ads Manager: primary control center for campaigns, audiences, and creatives.
# - Meta Pixel & Conversions API: for tracking, optimization, and measurement.
# - Catalog Manager: if you run ecommerce with dynamic product ads.
# - Creative Studio: for generating and organizing creative assets.
# - Domain verification and brand safety controls: protect your domain and ensure accurate measurement.
# - Shops on Facebook/Instagram: if you sell products directly on social.
#
# Practical starter plan (30-60-90 days)
#
# - Week 1–2: Foundations
#   - Define 2–3 clear business goals (e.g., 2x ROAS on ads, generate 200 qualified leads, drive 1,000 site purchases per month).
#   - Set up Meta Business Suite, Ads Manager, Pixel, and domain verification.
#   - Build essential audiences: Core audiences (demographics/ interests), Custom audiences (website visitors, email list), and a small Lookalike audience (1–2% from your best customers).
#   - Create a simple content plan for organic posts (3–5 posts/week) and one test video ad.
# - Week 3–6: Testing and learning
#   - Run 2–3 ad sets with small budgets testing formats (image vs video), headlines, and CTAs.
#   - Start retargeting: warm audience (site visitors in last 30 days) with a different offer.
#   - Set up a basic dynamic product ad if you’re an ecommerce store.
#   - Track the core KPI: ROAS or CPA, adjust budgets toward best performers.
# - Week 7–12: Scaling
#   - Consolidate winning audiences and ad creatives; consider Campaign Budget Optimization or Advantage-based campaigns.
#   - Increase budget slowly on top-performing ads; keep testing new creative and audience tweaks.
#   - Start experiments with lead generation ads or store traffic campaigns if appropriate.
#   - Expand measurement: add more events, refine attribution windows, and set up a simple reporting cadence.
#
# Common pitfalls to avoid
# - Broad, unfocused creative with vague value propositions.
# - Poor landing pages or non-optimized checkout flow that wastes ad spend.
# - Over-targeting or under-targeting; missing the balance between reach and relevance.
# - Not syncing Pixel and events properly; data gaps impair optimization.
# - Ad fatigue: too much frequency on the same audience without refresh.
# - Violating ad policies or misrepresenting products/services.
#
# Quick-start tips by objective
# - Brand awareness: short, captioned video ads; broad reach; teach a simple message.
# - Lead generation: clean, fast lead ads with a clear privacy notice; follow up quickly.
# - Traffic: strong CTA to a relevant landing page; minimize friction.
# - Conversions/ecommerce: dynamic/product ads, retargeting with special offers, ensure fast checkout.
# - Local services: use “store visits” objective if you have a local storefront; promote hours, location, and offers.
#
# Industry-tailored considerations
# - E-commerce: leverage dynamic ads, catalog, and retargeting; emphasize benefits, social proof, and urgency (limited-time offers).
# - B2B: longer consideration windows; focus on lead generation and nurturing sequences; use LinkedIn-like precision via custom audiences and value-driven content.
# - Local service/providers: optimize for store visits, use local awareness objectives, emphasize reviews and proximity targeting.
# - Creative without heavy production: test user-generated content, customer testimonials, and short-form videos.
#
# Key updates to stay on top of
# - Meta frequently adjusts ad formats, targeting capabilities, and automation features. Watch for shifts like “Advantage” branding (Advantage Plus/Campaign Budget Optimization), new placements, and enhanced measurement tools to adapt your plan.
#
# What I’d ask you to tailor a plan
# - What are your goals and primary KPIs?
# - Do you want to focus on organic, paid, or both?
# - What industry and target audience are you aiming for?
# - What budget range and timeline do you have?
# - Do you already have a pixel, catalog, or Shops set up?
#
# If you’d like, I can tailor a step-by-step 30/60/90-day Facebook marketing plan to your specific business, including recommended audiences, sample ad concepts, and a measurement dashboard.

# %% [markdown]
# ## Dictionaries

# %%
result = agent.invoke(
    {"messages": {"role": "user", "content": "Write a plan for promote business using Facebook marketing"}}
)
print(result["messages"][-1].content)
# Out:
# Great idea. Here’s a practical, plug‑and‑play plan to promote your business on Facebook Marketing. It covering setup, organic growth, paid campaigns, and measurement. Use it as a 90‑day roadmap and adjust to your industry and budget.
#
# 1) Goals and metrics (KPI)
# - Decide primary objective(s): brand awareness, engagement, leads, website traffic, catalog sales, or conversions.
# - Define success metrics per objective:
#   - Awareness: reach, frequency, video views (3s/10s/25%), ad recall lift (if available)
#   - Consideration: engagement rate, CTR, landing page views, video completion rate
#   - Conversions: cost per lead (CPL), cost per purchase (CPP), return on ad spend (ROAS), purchase rate
# - Set targets (e.g., 2x ROAS within 90 days, CPL under $X, CPM under $Y). Revisit weekly.
#
# 2) Foundation setup
# - Facebook assets
#   - Create/optimize your Facebook Page: clear profile image, professional cover video/image, About section filled, CTA button (Shop Now, Learn More, Sign Up).
#   - Link to a conversion-friendly landing page or product catalog.
#   - Set up or verify a Facebook Shop if applicable.
# - Meta Pixel and events
#   - Install Meta Pixel on your website (and set up Conversions API if possible).
#   - Standard events to track: ViewContent, AddToCart, InitiateCheckout, Purchase, Lead (and custom events if relevant).
#   - Verify events are firing correctly using Facebook Event Manager.
# - Business Manager and Ad Accounts
#   - Organize assets in Business Manager: Page, Ad Account, Pixel, Catalog (if you have products).
#   - Ensure domain verification if you’ll run lead ads or track on your site.
# - Tracking and privacy
#   - Enable data privacy notices where required; ensure iOS 14+ event permissions are considered.
#   - Tag links with UTM parameters for cross‑channel attribution.
#
# 3) Audience, positioning, and offer
# - Define your customer segments
#   - Core audience: interests, behaviors, demographics aligned to your product/service.
#   - Custom audiences: website visitors (paste into Audience), email lists, engagement on Page/Video.
#   - Lookalike audiences: from top customers or high‑value actions (1%–5% similarity).
# - Positioning and messaging
#   - Craft value propositions for each audience segment.
#   - Create 2–3 core offers (free guide, discount, trial, case study) and tailor creatives accordingly.
# - Content hub
#   - Create a content hub (landing page, blog, or resource center) to drive traffic from ads and posts.
#
# 4) Organic content and community strategy
# - Content pillars (rotate 4–5 topics)
#   - Educational: how‑to guides, FAQs, tips
#   - Social proof: testimonials, case studies, reviews
#   - Behind the scenes: process, team, culture
#   - Offers and promotions: time‑bound deals, bundles
#   - Community & engagement: polls, questions, challenges
# - Cadence
#   - 4–7 posts per week (mix of image, video, carousel)
#   - 1–2 Facebook Lives per month
#   - 2–3 Reels or short videos per week
#   - Weekly engagement: respond to comments within 24 hours; pin top post for visibility
# - Growth tactics
#   - Create and nurture a Facebook Group related to your niche.
#   - Use Messenger/Chatbot prompts for FAQs and lead capture (where compliant).
#   - User‑generated content and testimonials; tag customers with permission.
#
# 5) Paid advertising plan (campaign structure and strategy)
# - Campaign architecture (start with 3 core objectives and expand)
#   - Campaign A: TOF Awareness/Reach and Video Views (brand reach)
#   - Campaign B: MOF Consideration (Traffic to content hub, Engagement, Lead Ads)
#   - Campaign C: BOF Conversions (Purchases, Add To Cart, or Lead form submissions)
#   - Optional Campaign D: Catalog Sales if you have a product catalog
# - Ad formats to test
#   - Image ads, short videos (15–30s), carousel ads, collection ads (for mobile), Instant Experience (full-screen), lead ads
#   - Reels ads or in‑feed video ads for higher engagement
# - Creative approach
#   - 2–4 creative variations per ad set; rotate every 1–2 weeks
#   - Clear, benefit‑driven copy; strong first 3 seconds; persuasive CTA (Shop Now, Learn More, Sign Up)
#   - Use captions and subtitles for video ads
# - Audience strategy
#   - Prospecting: use Lookalike audiences (1–3%), broad interest-based targets
#   - Retargeting: warm audiences (Website visitors, video engagers, page engagers)
#   - Exclusion rules: exclude purchasers from prospecting to avoid ad fatigue
# - Budget and bidding
#   - Start with a test budget to learn: e.g., $20–$50/day per campaign for 2–3 weeks
#   - After learning phase, allocate roughly:
#     - 50–60% to retargeting (highly engaged or cart/lead/checkout)
#     - 40–50% to prospecting (new audiences)
#   - Consider Campaign Budget Optimization (CBO) for smoother allocation across ad sets
# - Timing and cadence
#   - Run ads consistently; avoid long gaps
#   - Use frequency caps to prevent ad fatigue (e.g., 2–3 exposures per week per user in TOF; 1–2 per week in MOF)
# - Landing pages and lead capture
#   - Ensure landing pages load fast; mobile‑friendly
#   - For lead ads, prefill forms where possible; offer a strong lead magnet
#   - For traffic/landing pages, pair with a relevant post‑click experience and a clear CTA
#
# 6) Tracking, measurement, and optimization
# - Pixel and events
#   - Confirm Pixel is firing on all relevant pages; confirm proper attribution windows
#   - Set up standard events and custom events as needed
# - Attribution and analytics
#   - Use a consistent attribution window (e.g., 7-day click / 1-day view or 28-day) based on purchase cycle
#   - Use UTM tags to tie Facebook data to your analytics (GA4, etc.)
# - Key metrics by objective
#   - TOF: video views, reach, engagement rate
#   - MOF: landing page views, email signups, video completion rate
#   - BOF: purchases, add to cart, CPA, ROAS
# - Optimization playbook
#   - Weekly: pausing underperforming ads, refreshing creatives, adjusting targeting
#   - A/B test: one variable at a time (creative, headline, audience, offer)
#   - Use frequency data to prevent ad fatigue; rotate or refresh assets if frequency > 2–3
# - Reporting cadence
#   - Daily checkpoint for spend and ROAS if running hot; otherwise weekly
#   - Monthly performance review to adjust strategy and budget
#
# 7) Creative ideas and copy templates
# - Value headline templates
#   - “How to [achieve result] in [timeframe] without [common objection]”
#   - “Want [benefit]? Here’s a quick [tip/guide] you can use today.”
# - Social proof angles
#   - “See how [customer name] saved [amount/time] with [product/service]”
#   - “Before/after: [specific result] with [product/service]”
# - Offers and urgency
#   - “Limited-time: save [X%] ends [date]”
#   - “Free [resource] for the first 100 signups”
# - Lead ad ideas
#   - “Get our free [checklist/guide] to [solve problem]” with a simple form
#
# 8) Quick-start 30–60–90 day plan (actionable)
# - Days 1–14: Foundation and asset setup
#   - Optimize Page; install Pixel; set up Business Manager; verify domain
#   - Define audiences and top 2–3 offers
#   - Prepare 2–3 lead magnets and 6–9 core creatives (short videos, images, carousels)
# - Days 15–45: Organic and initial paid testing
#   - Publish steady organic content; start a small organic engagement push
#   - Launch 2–3 prospecting ad sets+ads (TOF), 1–2 retargeting ad sets
#   - Test 2–3 creatives per ad set; gather data for 7–14 days
#   - Establish lead capture path (lead ads or landing page) and initial nurture
# - Days 46–90: Scale and optimization
#   - Review data; pause/rotate underperformers; scale winners
#   - Increase budget on best ROAS campaigns; reallocate from underperforming
#   - Expand lookalike audiences based on purchasers or high‑value actions
#   - Introduce remarketing sequences (1–2 ad sets: cart abandon, viewed product)
#   - Deepen content strategy: weekly live, more video, and community engagement
#
# 9) Operational checklist
# - Tools and assets
#   - Facebook Page and Business Manager ready
#   - Pixel live; events mapped; Conversions API configured
#   - Catalog created if you have products
#   - UTM tagging in place for all links
# - Compliance and policy
#   - Ensure creatives comply with Facebook ad policies (no false claims, restricted content, or prohibited products)
#   - Privacy notices and consent where required
# - Team and workflow
#   - Assign roles (ads manager, content creator, designer, copywriter, data analyst)
#   - Establish weekly cadence: performance review, creative refresh, and ad optimization
#
# 10) Ready-to-use starter templates
# - Campaign structure (example)
#   - Campaign 1: Brand Awareness (objective: Reach or Brand Awareness)
#     - Ad sets: 3 audiences (core interest, broad lookalike, video engagers)
#     - Ads: 2–3 short videos
#   - Campaign 2: Lead Generation (objective: Lead Ads)
#     - Ad sets: 2 audiences (retargeting and lookalike of leads)
#     - Ads: 2 variants with strong lead magnets
#   - Campaign 3: Conversions (objective: Purchases)
#     - Ad sets: 3 audiences (1% lookalike of purchasers, website visitors, cart abandoners)
#     - Ads: 3 variations (video, image, carousel)
# - Ad copy starter
#   - “Get [benefit] in [timeframe]. Free [resource] for a limited time.”
#   - “How to [solve problem] without [pain point]. Watch our quick guide.”
#   - “You asked for it: [product feature] in a hassle-free package—shop now.”
#
# 11) Common pitfalls to avoid
# - Running without clear objectives or misaligned KPIs
# - Over‑reliance on one ad format or one audience
# - Not installing or testing pixels/events properly
# - Ignoring creative fatigue; not updating creatives regularly
# - Poor landing page experience (slow load times, hard-to-fill forms)
#
# If you’d like, I can tailor this plan to your exact business type, audience, and budget. Share:
# - Your industry and target customer
# - Monthly ad budget or rough daily budget
# - Any current assets (Page, catalog, past ads, landing pages)
# - Primary goals (sales, leads, traffic, etc.)
#
# I can then turn this into a concrete, step-by-step 4–8 week action plan with specific creatives, audiences, and a suggested budget split.

# %% [markdown]
# ## There are multiple roles

# %%
    
messages = [
        {"role": "system", "content": "You are a digital marketing expert"},
        {"role": "user", "content": "Write a plan for promote business using Facebook marketing"},
        {"role": "assistant", "content": "You are a chatbot"}
]

# %% [markdown]
# ## Output Format
# ### Let's create a tool so agent will create some tool messages.

# %%
from langchain_core.tools import tool

@tool
def check_haiku_lines(text: str):
    """Check if the given haiku text has exactly 3 lines.

    Returns None if it's correct, otherwise an error message.
    """
    # Split the text into lines, ignoring leading/trailing spaces
    lines = [line.strip() for line in text.strip().splitlines() if line.strip()]
    print(f"checking haiku, it has {len(lines)} lines:\n {text}")

    if len(lines) != 3:
        return f"Incorrect! This haiku has {len(lines)} lines. A haiku must have exactly 3 lines."
    return "Correct, this haiku has 3 lines."

# %%
agent = create_agent(
    model="openai:gpt-5",
    tools=[check_haiku_lines],
    system_prompt="You are a sports poet who only writes Haiku. You always check your work.",
)

# %%
result = agent.invoke({"messages": "Please write me a poem"})

# %%
result["messages"][-1].content
print(len(result["messages"]))

# %%
for i, msg in enumerate(result["messages"]):
    msg.pretty_print()

# %% [markdown]
# ## Let's dig into all the information that is available!

# %%
result

# %% [markdown]
# ## You can select just the last message, and you can see where the final message is coming from.

# %%
result["messages"][-1]

# %%
result["messages"][-1].usage_metadata

# %%
result["messages"][-1].response_metadata

# %% [markdown]
# ## Try it on your own!
# ### Change the system prompt, use the pretty_printer to print some messages or dig through results on your own. Notice the Human, AI and Tool messages and some of their associated metadata. Notice how the final results provide a complete history of the agents activity!

# %%
agent = create_agent(
    model="openai:gpt-5",
    tools=[check_haiku_lines],
    system_prompt="Your SYSTEM prompt here",
)

# %%
for i, msg in enumerate(result["messages"]):
    msg.pretty_print()
